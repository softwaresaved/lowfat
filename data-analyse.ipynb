# %% [markdown]
# # Data Analyse
#
# If you want to do your own analyse of the data on `db.sqlite3` and are going to use Python you can take advantage of some Django code. This Jupyter Notebook will help you to enable the Django code.

# %% [markdown]
# ## Setup and run
#
# To setup your environment to run this Jupyter notebook you need to install some packages. Our suggestion is to run
#
# ~~~
# $ python -m pip install -r requirements.txt
# $ python -m pip install -r requirements-jupyter.txt
# ~~~
#
# from your terminal.
#
# To start Jupyter server, run
#
# ~~~
# $ python manage.py shell_plus --notebook
# ~~~

# %% [markdown]
# ## Basic (Django Part)
#
# You can use all power of Django on the notebook. For example, to gain access to the models you can use

# %%
import lowfat.models as models

# %% [markdown]
# To select all the fellows you can use

# %%
fellows = models.Claimant.objects.filter(fellow=True)
fellows
# Out:
# <QuerySet [<Claimant: Black Widow (2017 ✓)>, <Claimant: The Hulk (2017 ✓)>, <Claimant: Green Arrow (2016 ✓)>, <Claimant: Iron Man (2016 ✓)>, <Claimant: Captain America (2015 ✓)>]>

# %% [markdown]
# Remember that the `Claimant` table can have entries that aren't fellows and because of it we need to use `.filter(selected=True)`.

# %% [markdown]
# ## Basic (Pandas Part)
#
# You can use Pandas with Django.

# %%
import pandas as pd

fellows = pd.DataFrame(list(fellows.values()))
fellows
# Out:
#                     added affiliation  application_year  \
# 0 2016-07-07 14:59:46.412     College              2016
# 1 2016-07-07 14:59:46.412  University              2016
# 2 2016-07-07 14:59:46.412  University              2015
# 3 2016-07-07 14:59:46.412  University              2015
# 4 2016-07-07 14:59:46.412     College              2014
#
#    attended_collaborations_workshop  attended_inaugural_meeting bitbucket  \
# 0                             False                       False
# 1                             False                       False
# 2                             False                       False
# 3                             False                       False
# 4                             False                       False
#
#   career_stage_when_apply  carpentries_instructor claimantship_grant  \
# 0                       3                   False            3000.00
# 1                       3                   False            3000.00
# 2                       3                   False            3000.00
# 3                       3                   False            3000.00
# 4                       3                   False            3000.00
#
#    collaborator       ...        screencast_url             slug  surname  \
# 0         False       ...                            black-widow    Widow
# 1         False       ...                               the-hulk     Hulk
# 2         False       ...                            green-arrow    Arrow
# 3         False       ...                               iron-man      Man
# 4         False       ...                        captain-america  America
#
#   terms_and_conditions_id         twitter                 updated user_id  \
# 0                    2017      BlackWidow 2018-02-06 15:48:04.747       3
# 1                    2017         TheHulk 2018-02-06 15:26:59.858       2
# 2                    2016      GreenArrow 2018-02-06 15:27:13.848       4
# 3                    2016         IronMan 2018-02-06 15:27:25.708       5
# 4                    2015  CaptainAmerica 2018-02-06 15:27:39.366       6
#
#                         website                       website_feed  \
# 0      http://black-widow.fake/      http://black-widow.fake/feed/
# 1         http://the-hulk.fake/         http://the-hulk.fake/feed/
# 2      http://green-arrow.fake/      http://green-arrow.fake/feed/
# 3         http://iron-man.fake/         http://iron-man.fake/feed/
# 4  http://captain-america.fake/  http://captain-america.fake/feed/
#
#   work_description
# 0            Work.
# 1             Work
# 2             Work
# 3             Tech
# 4             Work
#
# [5 rows x 54 columns]

# %% [markdown]
# When converting a Django `QuerySet` into a Pandas `DataFrame` you will need to as the previous example because so far Pandas can't process Django `QuerySet`s by default.

# %% [markdown]
# ### Pandas table as CSV and as Data URIs
#
# For the report, we need to Pandas table as CSV encoded inside data URIs so users can download the CSV file without querying the server.

# %%
from base64 import b64encode

csv = fellows.to_csv(
    header=True,
    index=False
)

b64encode(csv.encode())
# Out:
# b'...'

# %% [markdown]
# The output of `b64encode` can be included in
#
# ```
# <a download="fellows.csv" href="data:application/octet-stream;charset=utf-16le;base64,{{ b64encode_output | safe }}">Download the data as CSV.</a>
# ```
#
# so that user can download the data.

# %% [markdown]
# ## Basic (Tagulous)
#
# We use [Tagulous](http://radiac.net/projects/django-tagulous/) as a tag library.

# %%
funds = models.Fund.objects.all()
pd.DataFrame(list(funds.values()))
# Out:
#   ad_status                   added additional_info  \
# 0         V 2016-07-07 14:59:46.412
# 1         V 2016-07-07 14:59:46.412
# 2         V 2016-07-07 14:59:46.412
# 3         V 2016-07-07 14:59:46.412
# 4         H 2016-07-13 15:01:25.316
# 5         V 2016-07-07 14:59:46.412
# 6         H 2016-07-13 14:59:44.036
# 7         V 2016-07-07 14:59:46.412
# 8         V 2016-07-07 14:59:46.412
# 9         V 2016-07-13 14:58:08.260
#
#                     approved budget_approved budget_request_attendance_fees  \
# 0                        NaT         1500.00                           0.00
# 1 2018-05-23 09:42:48.686967          500.00                           0.00
# 2                        NaT         2000.00                           0.00
# 3                        NaT         2500.00                           0.00
# 4                        NaT            0.00                           0.00
# 5 2018-04-25 15:43:12.812000         2000.00                           0.00
# 6                        NaT            0.00                           0.00
# 7                        NaT         1000.00                           0.00
# 8                        NaT         1500.00                           0.00
# 9                        NaT          500.00                           0.00
#
#   budget_request_catering budget_request_others  \
# 0                  500.00                  0.00
# 1                    0.00                  0.00
# 2                    0.00                  0.00
# 3                    0.00                  0.00
# 4                    0.00                  0.00
# 5                    0.00                  0.00
# 6                 1000.00                  0.00
# 7                    0.00                  0.00
# 8                    0.00                  0.00
# 9                    0.00                  0.00
#
#   budget_request_subsistence_cost budget_request_travel         ...           \
# 0                            0.00               1000.00         ...
# 1                            0.00                500.00         ...
# 2                            0.00               2000.00         ...
# 3                            0.00               2500.00         ...
# 4                            0.00               1500.00         ...
# 5                         1000.00               2000.00         ...
# 6                            0.00                  0.00         ...
# 7                            0.00               1000.00         ...
# 8                            0.00               1500.00         ...
# 9                            0.00                500.00         ...
#
#          lat        lon  mandatory  notes_from_admin required_blog_posts  \
# 0   30.05180  -65.84834      False                                     1
# 1   30.05180  -65.84834      False                                     1
# 2  -13.13435  -90.89369      False                                     1
# 3    3.91522  102.71730      False                                     1
# 4   15.53126   48.89437      False                                     1
# 5  -20.63223 -178.32413      False                                     1
# 6  -73.47064   -9.87283      False                                     1
# 7   12.25341  173.44064      False                                     1
# 8  167.75629  -71.04731      False                                     1
# 9   46.95474   -6.73372      False                                     1
#
#    start_date  status                       title                    updated  \
# 0  2016-09-25       P      9d6816aa - Black Widow 2016-09-05 10:53:16.027000
# 1  2016-08-01       A      9d6816de - Black Widow 2018-05-23 09:42:48.687343
# 2  2016-06-16       F  9d681148 - Captain America 2018-05-23 09:42:58.142582
# 3  2016-05-14       F      9d68144a - Green Arrow 2018-04-25 15:42:47.952000
# 4  2015-07-01       R      9d681d8c - Green Arrow 2016-09-05 10:51:42.337000
# 5  2015-05-14       A         9d683330 - The Hulk 2018-04-25 15:43:12.814000
# 6  2014-11-10       F  9d681b66 - Captain America 2018-04-25 15:43:45.278000
# 7  2014-05-20       F         9d680716 - Iron Man 2018-05-23 09:43:21.692780
# 8  2014-05-16       F         9d680248 - Iron Man 2018-04-25 15:46:51.513000
# 9  2014-02-20       R  9d6818e6 - Captain America 2016-07-17 14:09:23.715000
#
#                    url
# 0  http://9d6816aa.com
# 1  http://9d6816de.com
# 2  http://9d681148.com
# 3  http://9d68144a.com
# 4  http://9d681d8c.com
# 5  http://9d683330.com
# 6  http://9d681b66.com
# 7  http://9d680716.com
# 8  http://9d680248.com
# 9  http://9d6818e6.com
#
# [10 rows x 35 columns]

# %% [markdown]
# Get a list of all tags:

# %%
funds[0].activity.all()
# Out:
# <TagTreeModelQuerySet []>

# %% [markdown]
# You can loop over each tag:

# %%
for tag in funds[0].activity.all():
    print(tag.name)

# %% [markdown]
# Filter for a specific tag:

# %%
models.Fund.objects.filter(activity="ssi2/fellowship")
# Out:
# <CastTaggedQuerySet []>

# %% [markdown]
# You can query for part of the name of the tag:

# %%
models.Fund.objects.filter(activity__name__contains="fellowship")
# Out:
# <CastTaggedQuerySet []>

# %%
for fund in models.Fund.objects.filter(activity__name__contains="fellowship"):
    print("{} - {}".format(fund, fund.activity.all()))
