# %% [markdown]
# # Data Analyse
#
# If you want to do your own analyse of the data on `db.sqlite3` and are going to use Python you can take advantage of some Django code. This Jupyter Notebook will help you to enable the Django code.

# %% [markdown]
# ## Setup and run
#
# To setup your environment to run this Jupyter notebook you need to install some packages. Our suggestion is to run
#
# ~~~
# $ python -m pip install -r requirements.txt
# $ python -m pip install -r requirements-jupyter.txt
# ~~~
#
# from your terminal.
#
# To start Jupyter server, run
#
# ~~~
# $ python manage.py shell_plus --notebook
# ~~~

# %% [markdown]
# ## Basic (Django Part)
#
# You can use all power of Django on the notebook. For example, to gain access to the models you can use

# %%
import lowfat.models as models

# %% [markdown]
# To select all the fellows you can use

# %%
fellows = models.Claimant.objects.filter(fellow=True)
fellows
# Out:
# <QuerySet [<Claimant: Black Widow (2017 ✓)>, <Claimant: The Hulk (2017 ✓)>, <Claimant: Green Arrow (2016 ✓)>, <Claimant: Iron Man (2016 ✓)>, <Claimant: Captain America (2015 ✓)>]>

# %% [markdown]
# Remember that the `Claimant` table can have entries that aren't fellows and because of it we need to use `.filter(selected=True)`.

# %% [markdown]
# ## Basic (Pandas Part)
#
# You can use Pandas with Django.

# %%
from django_pandas.io import read_frame

fellows = read_frame(fellows.values())
fellows
# Out:
#    id  user_id forenames  surname                     email          phone  \
# 0   4        3     Black    Widow    b.widow@averengers.com  +441111111114
# 1   5        2       The     Hulk     t.hulk@averengers.com  +441111111115
# 2   3        4     Green    Arrow    g.arrow@averengers.com  +441111111113
# 3   2        5      Iron      Man      i.man@averengers.com  +441111111112
# 4   1        6   Captain  America  c.america@averengers.com  +441111111111
#
#            gender    home_country home_city home_lon           ...            \
# 0          Female  United Kingdom         L     None           ...
# 1            Male  United Kingdom         S     None           ...
# 2            Male  United Kingdom         L     None           ...
# 3  Rather not say  United Kingdom         B     None           ...
# 4            Male  United Kingdom         L     None           ...
#
#   research_software_engineer claimantship_grant attended_inaugural_meeting  \
# 0                      False            3000.00                      False
# 1                      False            3000.00                      False
# 2                      False            3000.00                      False
# 3                      False            3000.00                      False
# 4                      False            3000.00                      False
#
#   attended_collaborations_workshop notes_from_admin screencast_url  \
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
#
#   example_of_writing_url mentor_id                   added  \
# 0                             None 2016-07-07 14:59:46.412
# 1                             None 2016-07-07 14:59:46.412
# 2                             None 2016-07-07 14:59:46.412
# 3                             None 2016-07-07 14:59:46.412
# 4                             None 2016-07-07 14:59:46.412
#
#                   updated
# 0 2018-02-06 15:48:04.747
# 1 2018-02-06 15:26:59.858
# 2 2018-02-06 15:27:13.848
# 3 2018-02-06 15:27:25.708
# 4 2018-02-06 15:27:39.366
#
# [5 rows x 54 columns]

# %% [markdown]
# When converting a Django `QuerySet` into a Pandas `DataFrame` you will need to as the previous example because so far Pandas can't process Django `QuerySet`s by default.

# %%
expenses = read_frame(Expense.objects.all())
expenses
# Out:
#    id  relative_number invoice_reference                            fund  \
# 0   1                1              None  9d681b66 - Captain America (8)
# 1   7                1              None      9d6816de - Black Widow (6)
# 2   5                1              None      9d68144a - Green Arrow (5)
# 3   8                1              None         9d680716 - Iron Man (4)
# 4   3                1              None  9d681148 - Captain America (3)
# 5   2                1              None         9d683330 - The Hulk (2)
# 6   4                1              None         9d680248 - Iron Man (1)
# 7   6                2              None         9d680248 - Iron Man (1)
#
#               claim amount_claimed justification_for_extra  invoice  final  \
# 0  expenses/ec7.pdf         500.00                            False  False
# 1  expenses/ec8.pdf         500.00                            False  False
# 2  expenses/ec6.pdf        2500.00                            False  False
# 3  expenses/ec5.pdf        1000.00                            False  False
# 4  expenses/ec4.pdf         400.00                            False  False
# 5  expenses/ec3.pdf       20000.00                            False  False
# 6  expenses/ec1.pdf        1000.00                            False  False
# 7  expenses/ec2.pdf         500.00                            False  False
#
#    advance_booking            ...             recipient_connection  \
# 0            False            ...
# 1            False            ...
# 2            False            ...
# 3            False            ...
# 4            False            ...
# 5            False            ...
# 6            False            ...
# 7            False            ...
#
#        status asked_for_authorization_date send_to_finance_date  \
# 0    Approved                   2016-07-17           2016-07-17
# 1  Processing                   2016-07-17           2016-07-17
# 2    Approved                   2016-07-17           2016-07-17
# 3    Approved                   2016-07-17           2016-07-17
# 4    Approved                   2016-07-17           2016-07-17
# 5  Processing                   2016-07-17           2016-07-17
# 6  Processing                         None                 None
# 7    Approved                   2016-07-17           2016-07-17
#
#   amount_authorized_for_payment                      grant_heading  \
# 0                        500.00  Grant (inauguration claimantship)
# 1                        500.00  Grant (inauguration claimantship)
# 2                       2500.00  Grant (inauguration claimantship)
# 3                       1000.00  Grant (inauguration claimantship)
# 4                        400.00  Grant (inauguration claimantship)
# 5                       2000.00  Grant (inauguration claimantship)
# 6                          0.00          Continuing (claimantship)
# 7                        500.00  Grant (inauguration claimantship)
#
#                                          grant notes_from_admin  \
# 0  Software Sustainability Institute - Phase 1
# 1  Software Sustainability Institute - Phase 1
# 2  Software Sustainability Institute - Phase 2
# 3  Software Sustainability Institute - Phase 2
# 4  Software Sustainability Institute - Phase 1
# 5  Software Sustainability Institute - Phase 1
# 6  Software Sustainability Institute - Phase 1
# 7  Software Sustainability Institute - Phase 1
#
#                     added                    updated
# 0 2016-07-13 15:05:50.610 2018-06-28 13:29:50.166798
# 1 2016-07-13 15:05:22.698 2018-06-28 13:29:50.168534
# 2 2016-07-13 15:04:56.919 2018-06-28 13:29:50.169480
# 3 2016-07-13 15:04:23.530 2018-06-28 13:29:50.170184
# 4 2016-07-13 15:03:57.771 2018-06-28 13:29:50.170822
# 5 2016-07-13 15:03:29.250 2018-06-28 13:29:50.171459
# 6 2016-07-07 14:59:46.412 2018-06-28 13:29:50.172069
# 7 2016-07-07 14:59:46.412 2018-06-28 13:29:50.172818
#
# [8 rows x 24 columns]

# %%
expenses.sum()
# Out:
# id                                                                              36
# relative_number                                                                  9
# invoice_reference                                                                0
# fund                             9d681b66 - Captain America (8)9d6816de - Black...
# claim                            expenses/ec7.pdfexpenses/ec8.pdfexpenses/ec6.p...
# amount_claimed                                                            26400.00
# justification_for_extra
# invoice                                                                          0
# final                                                                            0
# advance_booking                                                                  0
# recipient_fullname
# recipient_email
# recipient_affiliation
# recipient_group
# recipient_connection
# status                           ApprovedProcessingApprovedApprovedApprovedProc...
# amount_authorized_for_payment                                              7400.00
# grant_heading                    Grant (inauguration claimantship)Grant (inaugu...
# grant                            Software Sustainability Institute - Phase 1Sof...
# notes_from_admin
# dtype: object

# %%
expenses["amount_authorized_for_payment"].sum()
# Out:
# Decimal('7400.00')

# %% [markdown]
# ### Pandas table as CSV and as Data URIs
#
# For the report, we need to Pandas table as CSV encoded inside data URIs so users can download the CSV file without querying the server.

# %%
from base64 import b64encode

csv = fellows.to_csv(
    header=True,
    index=False
)

b64encode(csv.encode())
# Out:
# b'...'

# %% [markdown]
# The output of `b64encode` can be included in
#
# ```
# <a download="fellows.csv" href="data:application/octet-stream;charset=utf-16le;base64,{{ b64encode_output | safe }}">Download the data as CSV.</a>
# ```
#
# so that user can download the data.

# %% [markdown]
# ## Basic (Tagulous)
#
# We use [Tagulous](http://radiac.net/projects/django-tagulous/) as a tag library.

# %%
funds = models.Fund.objects.all()
read_frame(funds)
# Out:
#    id                  claimant    category          focus  mandatory  \
# 0  10      Black Widow (2017 ✓)  Organising  Cross cutting      False
# 1   6      Black Widow (2017 ✓)   Attending  Cross cutting      False
# 2   3  Captain America (2015 ✓)  Organising  Cross cutting      False
# 3   5      Green Arrow (2016 ✓)   Attending  Cross cutting      False
# 4   9      Green Arrow (2016 ✓)   Attending  Cross cutting      False
# 5   2         The Hulk (2017 ✓)  Organising  Cross cutting      False
# 6   8  Captain America (2015 ✓)   Attending  Cross cutting      False
# 7   4         Iron Man (2016 ✓)  Organising  Cross cutting      False
# 8   1         Iron Man (2016 ✓)   Attending  Cross cutting      False
# 9   7  Captain America (2015 ✓)   Attending  Cross cutting      False
#
#                         title                  url         country city  \
# 0      9d6816aa - Black Widow  http://9d6816aa.com  United Kingdom    U
# 1      9d6816de - Black Widow  http://9d6816de.com  United Kingdom    U
# 2  9d681148 - Captain America  http://9d681148.com  United Kingdom    U
# 3      9d68144a - Green Arrow  http://9d68144a.com  United Kingdom    U
# 4      9d681d8c - Green Arrow  http://9d681d8c.com  United Kingdom    U
# 5         9d683330 - The Hulk  http://9d683330.com  United Kingdom    U
# 6  9d681b66 - Captain America  http://9d681b66.com  United Kingdom    U
# 7         9d680716 - Iron Man  http://9d680716.com  United Kingdom    U
# 8         9d680248 - Iron Man  http://9d680248.com  United Kingdom    U
# 9  9d6818e6 - Captain America  http://9d6818e6.com  United Kingdom    U
#
#          lon           ...            can_be_advertise_after ad_status  \
# 0  -65.84834           ...                              True   Visible
# 1  -65.84834           ...                             False   Visible
# 2  -90.89369           ...                              True   Visible
# 3  102.71730           ...                             False   Visible
# 4   48.89437           ...                             False      Hide
# 5 -178.32413           ...                             False   Visible
# 6   -9.87283           ...                             False      Hide
# 7  173.44064           ...                              True   Visible
# 8  -71.04731           ...                             False   Visible
# 9   -6.73372           ...                             False   Visible
#
#        status required_blog_posts                      grant_heading  \
# 0  Processing                   1  Grant (inauguration claimantship)
# 1    Approved                   1  Grant (inauguration claimantship)
# 2    Archived                   1  Grant (inauguration claimantship)
# 3    Archived                   1  Grant (inauguration claimantship)
# 4    Rejected                   1  Grant (inauguration claimantship)
# 5    Approved                   1  Grant (inauguration claimantship)
# 6    Archived                   1  Grant (inauguration claimantship)
# 7    Archived                   1  Grant (inauguration claimantship)
# 8    Archived                   1  Grant (inauguration claimantship)
# 9    Rejected                   1  Grant (inauguration claimantship)
#
#                                          grant notes_from_admin  \
# 0  Software Sustainability Institute - Phase 2
# 1  Software Sustainability Institute - Phase 2
# 2  Software Sustainability Institute - Phase 2
# 3  Software Sustainability Institute - Phase 2
# 4  Software Sustainability Institute - Phase 2
# 5  Software Sustainability Institute - Phase 2
# 6  Software Sustainability Institute - Phase 1
# 7  Software Sustainability Institute - Phase 2
# 8  Software Sustainability Institute - Phase 2
# 9  Software Sustainability Institute - Phase 1
#
#                     added                approved                 updated
# 0 2016-07-07 14:59:46.412                     NaT 2016-09-05 10:53:16.027
# 1 2016-07-07 14:59:46.412 2018-04-25 15:39:50.987 2018-04-25 15:39:50.988
# 2 2016-07-07 14:59:46.412                     NaT 2018-04-25 15:41:04.259
# 3 2016-07-07 14:59:46.412                     NaT 2018-04-25 15:42:47.952
# 4 2016-07-13 15:01:25.316                     NaT 2016-09-05 10:51:42.337
# 5 2016-07-07 14:59:46.412 2018-04-25 15:43:12.812 2018-04-25 15:43:12.814
# 6 2016-07-13 14:59:44.036                     NaT 2018-04-25 15:43:45.278
# 7 2016-07-07 14:59:46.412                     NaT 2018-04-25 15:44:21.987
# 8 2016-07-07 14:59:46.412                     NaT 2018-04-25 15:46:51.513
# 9 2016-07-13 14:58:08.260                     NaT 2016-07-17 14:09:23.715
#
# [10 rows x 35 columns]

# %% [markdown]
# Get a list of all tags:

# %%
funds[0].activity.all()
# Out:
# <TagTreeModelQuerySet []>

# %% [markdown]
# You can loop over each tag:

# %%
for tag in funds[0].activity.all():
    print(tag.name)

# %% [markdown]
# Filter for a specific tag:

# %%
models.Fund.objects.filter(activity="ssi2/fellowship")
# Out:
# <CastTaggedQuerySet []>

# %% [markdown]
# You can query for part of the name of the tag:

# %%
models.Fund.objects.filter(activity__name__contains="fellowship")
# Out:
# <CastTaggedQuerySet []>

# %%
for fund in models.Fund.objects.filter(activity__name__contains="fellowship"):
    print("{} - {}".format(fund, fund.activity.all()))
